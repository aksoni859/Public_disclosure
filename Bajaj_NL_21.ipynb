# %%
# Import Libraries
import camelot
import os
import numpy as np
import pandas as pd

# Fill data as per requirement
company = 'Bajaj_Allianz'
financial_yr = '2020_21'
quarter = 'Q4'


LOB = ['Fire', 'Marine Cargo', 'Marine Others', 'Marine Total', 'Motor OD', 'Motor TP', 'Motor Total', 'Liability', 'Engineering', 'PA', 'Health Insurance', 'Crop Insurance', 'Others']
year = np.full(shape=len(LOB),fill_value=financial_yr)
qtr = np.full(shape=len(LOB),fill_value=quarter)
cmpny = np.full(shape=len(LOB),fill_value=company.replace('_',' '))

dir_path = r"C:\Users\n179950\Munich Re\MR India NL - Documents\Agro\6. Miscellaneous\Individual's Folders\Anil\project_public_disclosure\PDF"
file = os.path.join(dir_path,company,financial_yr,quarter,'NL-21.pdf')
print(file)

odir_path = r"C:\Users\n179950\Munich Re\MR India NL - Documents\Agro\6. Miscellaneous\Individual's Folders\Anil\project_public_disclosure\CSV"
ofile = os.path.join(odir_path,company,financial_yr,quarter,'NL-21.csv')
print(ofile)
# Out:
# C:\Users\n179950\Munich Re\MR India NL - Documents\Agro\6. Miscellaneous\Individual's Folders\Anil\project_public_disclosure\PDF\Bajaj_Allianz\2020_21\Q4\NL-21.pdf
# C:\Users\n179950\Munich Re\MR India NL - Documents\Agro\6. Miscellaneous\Individual's Folders\Anil\project_public_disclosure\CSV\Bajaj_Allianz\2020_21\Q4\NL-21.csv

# %%
def chk_blank(value):
    if value =='-' and len(value)==1:
        return None
    elif len(value)==0:
        return None
    elif '(' in value:
        return int(value.replace('-','').replace('(','').replace(')','').replace(' ','')) *-1
    else:
        return int(value.replace('-','').replace(' ',''))
    
def ifnone(value):
    if value == None:
        return 0
    else:
        return value

# %%
tables = camelot.read_pdf(file)#,pages="all")
print("Total tables extracted:", tables.n)
# Out:
# Total tables extracted: 1

# %%
tables[0].df.head(50)
# Out:
#                            0                     1  \
# 0   Statement of Liabilities
# 1
# 2                     Sl.No.            Particular
# 3                          1                  Fire
# 4                          2                Marine
# 5                          a          Marine Cargo
# 6                          b           Marine Hull
# 7                          3         Miscellaneous
# 8                          a                 Motor
# 9                          b           Engineering
# 10                         c              Aviation
# 11                         d           Liabilities
# 12                         e  Workmen Compensation
# 13                         f                Others
# 14                         4      Health Insurance
# 15                               Total Liabilities
#
#                                  2                                   3  \
# 0
# 1                As at 31 Mar 2021
# ...

# %%
##### Read Data from NL21 form

# Reserve for Unexpired Risk
Reserve_for_unexpired_risks = []

Reserve_for_unexpired_risks_business_Fire = chk_blank(tables[0].df[2][3].replace(',',''))
Reserve_for_unexpired_risks_business_Marine_cargo = chk_blank(tables[0].df[2][5].replace(',',''))
Reserve_for_unexpired_risks_business_Marine_others = chk_blank(tables[0].df[2][6].replace(',',''))
Reserve_for_unexpired_risks_business_Marine_total = Reserve_for_unexpired_risks_business_Marine_cargo + Reserve_for_unexpired_risks_business_Marine_others
Reserve_for_unexpired_risks_business_Motor_OD = None
Reserve_for_unexpired_risks_business_Motor_TP = None
Reserve_for_unexpired_risks_business_Motor_Total = chk_blank(tables[0].df[2][8].replace(',',''))
Reserve_for_unexpired_risks_business_worksmens = chk_blank(tables[0].df[2][12].replace(',',''))
Reserve_for_unexpired_risks_business_Liability = chk_blank(tables[0].df[2][11].replace(',',''))
Reserve_for_unexpired_risks_business_Engineering = chk_blank(tables[0].df[2][9].replace(',',''))
Reserve_for_unexpired_risks_business_aviation = chk_blank(tables[0].df[2][10].replace(',',''))
Reserve_for_unexpired_risks_business_PA = None
Reserve_for_unexpired_risks_business_Health_Insurance = chk_blank(tables[0].df[2][14].replace(',',''))
Reserve_for_unexpired_risks_business_Credit_Insurance = None
Reserve_for_unexpired_risks_business_Crop_Insurance = None
Reserve_for_unexpired_risks_business_Others = chk_blank(tables[0].df[2][13].replace(',',''))


### Add others all LoB
Reserve_for_unexpired_risks_business_Others = ifnone(Reserve_for_unexpired_risks_business_Others) + ifnone(Reserve_for_unexpired_risks_business_worksmens) \
                               + ifnone(Reserve_for_unexpired_risks_business_aviation) + ifnone(Reserve_for_unexpired_risks_business_Credit_Insurance)

Reserve_for_unexpired_risks.append(Reserve_for_unexpired_risks_business_Fire)
Reserve_for_unexpired_risks.append(Reserve_for_unexpired_risks_business_Marine_cargo)
Reserve_for_unexpired_risks.append(Reserve_for_unexpired_risks_business_Marine_others)
Reserve_for_unexpired_risks.append(Reserve_for_unexpired_risks_business_Marine_total)
Reserve_for_unexpired_risks.append(Reserve_for_unexpired_risks_business_Motor_OD)
Reserve_for_unexpired_risks.append(Reserve_for_unexpired_risks_business_Motor_TP)
Reserve_for_unexpired_risks.append(Reserve_for_unexpired_risks_business_Motor_Total)
Reserve_for_unexpired_risks.append(Reserve_for_unexpired_risks_business_Liability)
Reserve_for_unexpired_risks.append(Reserve_for_unexpired_risks_business_Engineering)
Reserve_for_unexpired_risks.append(Reserve_for_unexpired_risks_business_PA)
Reserve_for_unexpired_risks.append(Reserve_for_unexpired_risks_business_Health_Insurance)
Reserve_for_unexpired_risks.append(Reserve_for_unexpired_risks_business_Crop_Insurance)
Reserve_for_unexpired_risks.append(Reserve_for_unexpired_risks_business_Others)

# %%
Reserve_for_unexpired_risks
# Out:
# [28963,
#  3009,
#  20,
#  3029,
#  None,
#  None,
#  253263,
#  810,
#  1547,
#  None,
#  83680,
#  None,
#  45306]

# %%
##### Read Data from NL21 form

# Reserve for Outstanding claims
Reserve_for_outstanding_claims = []

Reserve_for_outstanding_claims_business_Fire = chk_blank(tables[0].df[3][3].replace(',',''))
Reserve_for_outstanding_claims_business_Marine_cargo = chk_blank(tables[0].df[3][5].replace(',',''))
Reserve_for_outstanding_claims_business_Marine_others = chk_blank(tables[0].df[3][6].replace(',',''))
Reserve_for_outstanding_claims_business_Marine_total = Reserve_for_outstanding_claims_business_Marine_cargo + Reserve_for_outstanding_claims_business_Marine_others
Reserve_for_outstanding_claims_business_Motor_OD = None
Reserve_for_outstanding_claims_business_Motor_TP = None
Reserve_for_outstanding_claims_business_Motor_Total = chk_blank(tables[0].df[3][8].replace(',',''))
Reserve_for_outstanding_claims_business_worksmens = chk_blank(tables[0].df[3][12].replace(',',''))
Reserve_for_outstanding_claims_business_Liability = chk_blank(tables[0].df[3][11].replace(',',''))
Reserve_for_outstanding_claims_business_Engineering = chk_blank(tables[0].df[3][9].replace(',',''))
Reserve_for_outstanding_claims_business_aviation = chk_blank(tables[0].df[3][10].replace(',',''))
Reserve_for_outstanding_claims_business_PA = None
Reserve_for_outstanding_claims_business_Health_Insurance = chk_blank(tables[0].df[3][14].replace(',',''))
Reserve_for_outstanding_claims_business_Credit_Insurance = None
Reserve_for_outstanding_claims_business_Crop_Insurance = None
Reserve_for_outstanding_claims_business_Others = chk_blank(tables[0].df[3][13].replace(',',''))


### Add others all LoB
Reserve_for_outstanding_claims_business_Others = ifnone(Reserve_for_outstanding_claims_business_Others) + ifnone(Reserve_for_outstanding_claims_business_worksmens) \
                               + ifnone(Reserve_for_outstanding_claims_business_aviation) + ifnone(Reserve_for_outstanding_claims_business_Credit_Insurance)

Reserve_for_outstanding_claims.append(Reserve_for_outstanding_claims_business_Fire)
Reserve_for_outstanding_claims.append(Reserve_for_outstanding_claims_business_Marine_cargo)
Reserve_for_outstanding_claims.append(Reserve_for_outstanding_claims_business_Marine_others)
Reserve_for_outstanding_claims.append(Reserve_for_outstanding_claims_business_Marine_total)
Reserve_for_outstanding_claims.append(Reserve_for_outstanding_claims_business_Motor_OD)
Reserve_for_outstanding_claims.append(Reserve_for_outstanding_claims_business_Motor_TP)
Reserve_for_outstanding_claims.append(Reserve_for_outstanding_claims_business_Motor_Total)
Reserve_for_outstanding_claims.append(Reserve_for_outstanding_claims_business_Liability)
Reserve_for_outstanding_claims.append(Reserve_for_outstanding_claims_business_Engineering)
Reserve_for_outstanding_claims.append(Reserve_for_outstanding_claims_business_PA)
Reserve_for_outstanding_claims.append(Reserve_for_outstanding_claims_business_Health_Insurance)
Reserve_for_outstanding_claims.append(Reserve_for_outstanding_claims_business_Crop_Insurance)
Reserve_for_outstanding_claims.append(Reserve_for_outstanding_claims_business_Others)

# %%
Reserve_for_outstanding_claims
# Out:
# [19429,
#  5743,
#  109,
#  5852,
#  None,
#  None,
#  339437,
#  541,
#  692,
#  None,
#  10426,
#  None,
#  21184]

# %%
##### Read Data from NL21 form

# IBNR Reserves
IBNR = []

IBNR_business_Fire = chk_blank(tables[0].df[4][3].replace(',',''))
IBNR_business_Marine_cargo = chk_blank(tables[0].df[4][5].replace(',',''))
IBNR_business_Marine_others = chk_blank(tables[0].df[4][6].replace(',',''))
IBNR_business_Marine_total = IBNR_business_Marine_cargo + IBNR_business_Marine_others
IBNR_business_Motor_OD = None
IBNR_business_Motor_TP = None
IBNR_business_Motor_Total = chk_blank(tables[0].df[4][8].replace(',',''))
IBNR_business_worksmens = chk_blank(tables[0].df[4][12].replace(',',''))
IBNR_business_Liability = chk_blank(tables[0].df[4][11].replace(',',''))
IBNR_business_Engineering = chk_blank(tables[0].df[4][9].replace(',',''))
IBNR_business_aviation = chk_blank(tables[0].df[4][10].replace(',',''))
IBNR_business_PA = None
IBNR_business_Health_Insurance = chk_blank(tables[0].df[4][14].replace(',',''))
IBNR_business_Credit_Insurance = None
IBNR_business_Crop_Insurance = None
IBNR_business_Others = chk_blank(tables[0].df[4][13].replace(',',''))


### Add others all LoB
IBNR_business_Others = ifnone(IBNR_business_Others) + ifnone(IBNR_business_worksmens) \
                               + ifnone(IBNR_business_aviation) + ifnone(IBNR_business_Credit_Insurance)

IBNR.append(IBNR_business_Fire)
IBNR.append(IBNR_business_Marine_cargo)
IBNR.append(IBNR_business_Marine_others)
IBNR.append(IBNR_business_Marine_total)
IBNR.append(IBNR_business_Motor_OD)
IBNR.append(IBNR_business_Motor_TP)
IBNR.append(IBNR_business_Motor_Total)
IBNR.append(IBNR_business_Liability)
IBNR.append(IBNR_business_Engineering)
IBNR.append(IBNR_business_PA)
IBNR.append(IBNR_business_Health_Insurance)
IBNR.append(IBNR_business_Crop_Insurance)
IBNR.append(IBNR_business_Others)

# %%
IBNR
# Out:
# [693, 1695, 49, 1744, None, None, 532589, 660, 404, None, 26101, None, 44277]

# %%
data = {'Year': year,
         'Qtr': qtr,
         'Company':cmpny,
         'LOB':LOB,
         'Reserves for unexpired risks': Reserve_for_unexpired_risks,
         'Reserve for Outstanding Claims':Reserve_for_outstanding_claims,
         'IBNR':IBNR}

# %%
df_data = pd.DataFrame(data)
df_data.to_csv(ofile,index=False)

# %%
df_data
# Out:
#        Year Qtr        Company               LOB  \
# 0   2020_21  Q4  Bajaj Allianz              Fire
# 1   2020_21  Q4  Bajaj Allianz      Marine Cargo
# 2   2020_21  Q4  Bajaj Allianz     Marine Others
# 3   2020_21  Q4  Bajaj Allianz      Marine Total
# 4   2020_21  Q4  Bajaj Allianz          Motor OD
# 5   2020_21  Q4  Bajaj Allianz          Motor TP
# 6   2020_21  Q4  Bajaj Allianz       Motor Total
# 7   2020_21  Q4  Bajaj Allianz         Liability
# 8   2020_21  Q4  Bajaj Allianz       Engineering
# 9   2020_21  Q4  Bajaj Allianz                PA
# 10  2020_21  Q4  Bajaj Allianz  Health Insurance
# 11  2020_21  Q4  Bajaj Allianz    Crop Insurance
# 12  2020_21  Q4  Bajaj Allianz            Others
#
#     Reserves for unexpired risks  Reserve for Outstanding Claims      IBNR
# 0                        28963.0                         19429.0     693.0
# 1                         3009.0                          5743.0    1695.0
# ...
